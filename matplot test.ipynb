# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(10)
y=np.random.randint(1,20,10)
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Title")
plt.show()
